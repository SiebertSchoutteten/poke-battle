# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import svm

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Inlezen van de dataset en overzicht

# %%
#Inlezen van de dataset
dataset = pd.read_csv('combats_big_super_train.csv',";")

df = pd.DataFrame(dataset)

dataset.head(10)
# Out:
#         poke1       poke2  leveldiff  attackdiff  defensediff  hpdiff  \
# 0    nidoking  victreebel          1         -13           12       1
# 1      golbat   charizard         -6          -4           -8      -3
# 2     rattata    nidoran♂         -9          -1           -5     -16
# 3    vaporeon     golduck         -5         -17          -18      50
# 4   poliwhirl    vaporeon          4           0            5     -65
# 5     poliwag     slowbro         -4         -25          -70     -55
# 6       doduo   vileplume          4           5          -40     -40
# 7  weepinbell      krabby          5         -15          -40      35
# 8    primeape     omastar          3          45          -65      -5
# 9      gastly  charmander          4         -17          -13      -9
#
#    specialdiff  speediff  powerdiff  effectivitydiff  ratingdiff    win
# 0          -25        14        120             0.00       -0.12  False
# 1          -10       -14          0            -1.75        0.19  False
# 2          -15        23         90             1.00        1.69   True
# 3           30       -30        -15            -1.00        0.28   True
# 4          -60        10        -55            -0.50        0.02  False
# 5          -40        50         40            -1.00        0.40  False
# 6          -65        12         85             2.00        0.32  False
# 7           60         4       -190             2.00       -0.65  False
# 8          -55        16        -15            -1.00        0.00  False
# 9           50         7        -20             4.00        1.46   True

# %%
x = df.select_dtypes(exclude=['number']) \
                .apply(LabelEncoder().fit_transform) \
                .join(df.select_dtypes(include=['number']))
        
x.head(10)
# Out:
#    poke1  poke2  win  leveldiff  attackdiff  defensediff  hpdiff  specialdiff  \
# 0     84    138    0          1         -13           12       1          -25
# 1     43     13    0         -6          -4           -8      -3          -10
# 2    113     87    1         -9          -1           -5     -16          -15
# 3    134     45    1         -5         -17          -18      50           30
# 4    104    134    0          4           0            5     -65          -60
# 5    103    123    0         -4         -25          -70     -55          -40
# 6     24    139    0          4           5          -40     -40          -65
# 7    144     67    0          5         -15          -40      35           60
# 8    108     93    0          3          45          -65      -5          -55
# 9     39     14    1          4         -17          -13      -9           50
#
#    speediff  powerdiff  effectivitydiff  ratingdiff
# 0        14        120             0.00       -0.12
# 1       -14          0            -1.75        0.19
# 2        23         90             1.00        1.69
# 3       -30        -15            -1.00        0.28
# 4        10        -55            -0.50        0.02
# 5        50         40            -1.00        0.40
# 6        12         85             2.00        0.32
# 7         4       -190             2.00       -0.65
# 8        16        -15            -1.00        0.00
# 9         7        -20             4.00        1.46

# %%
# Beschrijvende statistische analyse
x.describe()
# Out:
#                poke1          poke2            win     leveldiff  \
# count  100000.000000  100000.000000  100000.000000  100000.00000
# mean       73.932640      73.916660       0.505890       0.43487
# std        43.056379      42.986378       0.499968       5.65977
# min         0.000000       0.000000       0.000000      -9.00000
# 25%        37.000000      37.000000       0.000000      -4.00000
# 50%        74.000000      74.000000       1.000000       0.00000
# 75%       111.000000     111.000000       1.000000       5.00000
# max       148.000000     148.000000       1.000000      10.00000
#
#           attackdiff    defensediff         hpdiff    specialdiff  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       -0.260810      -0.129780      -0.062160       0.010240
# std        36.913776      37.983307      39.696857      39.191184
# min      -129.000000    -175.000000    -240.000000    -115.000000
# 25%       -25.000000     -25.000000     -20.000000     -25.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%        25.000000      25.000000      20.000000      25.000000
# max       129.000000     175.000000     240.000000     115.000000
#
#             speediff      powerdiff  effectivitydiff     ratingdiff
# count  100000.000000  100000.000000    100000.000000  100000.000000
# mean        1.140830      -0.120070         0.007938       0.001505
# std        45.334406      80.797139         1.879633       0.793190
# min      -267.000000    -405.000000       -13.000000      -3.060000
# 25%       -21.000000     -50.000000        -1.000000      -0.530000
# 50%         1.000000       0.000000         0.000000       0.000000
# 75%        23.000000      50.000000         1.000000       0.530000
# max       256.000000     465.000000        13.250000       3.010000

# %% [markdown]
# # Visualiseren van de dataset

# %%
# Histogram
x.hist(figsize=(15,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000204EDE682E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EE4B8A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EE563860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000204EE5B8390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EE9F0908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EE9F0940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000204EEC82E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EECDEC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EED1C0B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000204EEFCF048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EEFD9B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000204EF091E48>]], dtype=object)

# %%
# Box plot
x.plot(kind= 'box' , subplots=True, layout=(4,4), sharex=False, sharey=False, figsize=(10,8))
# Out:
# poke1                  Axes(0.125,0.71587;0.168478x0.16413)
# poke2               Axes(0.327174,0.71587;0.168478x0.16413)
# win                 Axes(0.529348,0.71587;0.168478x0.16413)
# leveldiff           Axes(0.731522,0.71587;0.168478x0.16413)
# attackdiff            Axes(0.125,0.518913;0.168478x0.16413)
# defensediff        Axes(0.327174,0.518913;0.168478x0.16413)
# hpdiff             Axes(0.529348,0.518913;0.168478x0.16413)
# specialdiff        Axes(0.731522,0.518913;0.168478x0.16413)
# speediff              Axes(0.125,0.321957;0.168478x0.16413)
# powerdiff          Axes(0.327174,0.321957;0.168478x0.16413)
# effectivitydiff    Axes(0.529348,0.321957;0.168478x0.16413)
# ratingdiff         Axes(0.731522,0.321957;0.168478x0.16413)
# dtype: object

# %%
# Correlation plot
Corr=x[x.columns].corr() 
sns.heatmap(Corr, annot=True)

# %% [markdown]
# # Preprocessing en opsplitsen in training en test set

# %%
# Opsplitsen in features en targets

features = list(x[['poke1','poke2','leveldiff','attackdiff','defensediff','hpdiff','specialdiff','speeddiff','powerdiff','effectivitydiff','ratingdiff']])
print(features),
X_train = x[features].values

y_train = x['win'].values


# Normalisatie van de dataset

scaler = preprocessing.StandardScaler().fit(X_train)  # Normaliseer naar gemiddelde = 0 en standaardafwijking = 1
#scaler = preprocessing.MaxAbsScaler().fit(X_train)   # Deel elke waarde door de absolute waarde van het maximum
#scaler = preprocessing.MinMaxScaler().fit(X_train)   # Trek van elke waar het min af en deel door (MAX - MIN)

X_train = scaler.transform(X_train)

print(X_train.shape)
# Out:
# ['pokemon1', 'pokemon2', 'lvldif', 'a1', 'a2', 'a3', 'a4', 'b1', 'b2', 'b3', 'b4']
# (10000, 11)
# D:\Programs\Anaconda\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# # Logistic regression

# %% [markdown]
# ## Initialiseren en trainen van de logistic regression classifier

# %%
#Inlezen van de dataset
dataset2 = pd.read_csv('combats_test.csv',';')

df2 = pd.DataFrame(dataset2)

dataset2.head(10)
# Out:
#            p1          p2  leveldif              a1             a2  \
# 0     dewgong  kangaskhan       -31     karate chop     mega drain
# 1   bulbasaur  victreebel       -38          sludge       meditate
# 2       gloom       zubat         6          tackle        screech
# 3     chansey        jynx        21     double kick     leech seed
# 4   poliwrath    clefairy       -21       ice punch  thunder shock
# 5        seel    nidoran♀        37        meditate    smokescreen
# 6  aerodactyl   electrode        21         reflect      mega kick
# 7    rapidash   blastoise       -64   thunder punch       meditate
# 8    rapidash     dewgong       -24          growth        pay day
# 9     dewgong      grimer        28  high jump kick        fissure
#
#             a3             a4             b1             b2            b3  \
# 0    waterfall     leech seed        disable           smog    hyper fang
# 1         surf      jump kick     hyper fang           gust  rolling kick
# 2       thrash          stomp          slash     horn drill   string shot
# 3  double kick            cut  poison powder      confusion   mirror move
# 4  string shot       withdraw         growth    thunderbolt    rock throw
# 5       sludge  poison powder    dizzy punch     substitute    solar beam
# 6         haze      twineedle    aurora beam       strength     fire spin
# 7        toxic     submission     sky attack           slam         ember
# 8   stun spore     rock throw   thunder wave  poison powder     confusion
# 9   fire blast      jump kick          clamp          swift    tri attack
#
#               b4    win
# 0    wing attack  False
# 1     skull bash  False
# 2          stomp   True
# 3     leech seed   True
# 4    horn attack  False
# 5         growth   True
# 6  thunder punch  False
# 7    comet punch  False
# 8    soft-boiled  False
# 9       headbutt   True

# %%
x2 = df2.select_dtypes(exclude=['number']) \
                .apply(LabelEncoder().fit_transform) \
                .join(df2.select_dtypes(include=['number']))
        
x2.head(10)
# Out:
#     p1   p2   a1   a2   a3   a4   b1   b2   b3   b4  win  leveldif
# 0   20   64   69   79  160   72   28  123   64  162    0       -31
# 1    9  139  122   78  140   68   64   55  109  117    0       -38
# 2   42  149  143  112  147  131  120   61  133  131    1         6
# 3   12   59   30   72   30   25   93   20   85   72    1        21
# 4  106   17   67  150  133  163   53  152  108   60    0       -21
# 5  122   87   78  124  122   93   29  137  126   53    1        37
# 6    1   33  104   80   57  156    5  132   43  149    0        21
# 7  112    8  149   78  153  136  118  119   39   18    0       -64
# 8  112   20   53   88  135  108  151   93   20  125    0       -24
# 9   20   48   59   44   41   68   17  141  155   58    1        28

# %%
# Opsplitsen in features en targets

features = list(x2[['p1','p2','leveldif','a1','a2','a3','a4','b1','b2','b3','b4']])
print(features)
X_test = x2[features].values

y_test= x2['win'].values

# Normalisatie van de dataset
X_test = scaler.transform(X_test)

print(X_test.shape)
# Out:
# ['p1', 'p2', 'leveldif', 'a1', 'a2', 'a3', 'a4', 'b1', 'b2', 'b3', 'b4']
# (2499, 11)
# D:\Programs\Anaconda\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Initialiseren van de logistic regression classifier

logreg = linear_model.LogisticRegression(C=1,class_weight= None)

#logreg = linear_model.LogisticRegression(C=1,class_weight= 'balanced')

# Training van het model
logreg.fit(X_train, y_train)

print('De bias = theta_0: ', logreg.intercept_)
print('De coefficienten theta: ',logreg.coef_)
# Out:
# De bias = theta_0:  [ 0.01993912]
# De coefficienten theta:  [[-0.01768931  0.02318075  3.27243816  0.02182835  0.04482777 -0.00768746
#    0.06622053  0.04574007 -0.00474873  0.04691544  0.04320349]]

# %% [markdown]
# ## Testen van het model op de test set

# %%
# Testen van het model op de test set

y_pred = logreg.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.85      0.85      1223
#           1       0.86      0.87      0.86      1276
#
# avg / total       0.86      0.86      0.86      2499
#
# [[1037  186]
#  [ 168 1108]]
# 85.8343337335

# %% [markdown]
# ## Predictie op een nieuwe patiënt
#
# Pregnancies:2 -
# Glucose: 132 -
# BloodPressure: 74 -
# SkinThickness:20 -
# Insulin:21 -
# BMI:24.3 -
# DiabetesPedigreeFunction:128 -
# Age: 37

# %%
patient = np.array([2,132,74,20,21,24.3,128,37])

# scaling
patient = scaler.transform(patient.reshape(1, -1))

print(patient)
y_patient = logreg.predict(patient.reshape(1,-1))
y_patient_prob = logreg.predict_proba(patient.reshape(1,-1))
print(y_patient)
print(y_patient_prob)

if y_patient == 0:
    print('Patiënt heeft geen diabetes')
else:
    print('Patiënt heeft diabetes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e0d42d84790e> in <module>()
#       2
#       3 # scaling
# ----> 4 patient = scaler.transform(patient.reshape(1, -1))
#       5
#       6 print(patient)
#
# D:\Programs\Anaconda\lib\site-packages\sklearn\preprocessing\data.py in transform(self, X, y, copy)
#     690         else:
#     691             if self.with_mean:
# --> 692                 X -= self.mean_
#     693             if self.with_std:
#     694                 X /= self.scale_
#
# ValueError: operands could not be broadcast together with shapes (1,8) (11,) (1,8)

# %% [markdown]
# # SVM zonder kernel (= lineaire kernel)

# %% [markdown]
# ## Initialiseren en trainen van SVM

# %%
SVMlinear = svm.SVC(kernel='linear',C=0.1)
SVMlinear.fit(X_train, y_train)
# Out:
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ## Testen van het model op test set

# %%
y_pred = SVMlinear.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.85      0.85      1223
#           1       0.85      0.86      0.86      1276
#
# avg / total       0.86      0.86      0.86      2499
#
# [[1036  187]
#  [ 174 1102]]
# 85.5542216887

# %% [markdown]
# ## Predictie op een nieuwe patiënt
#
# Pregnancies:2 -
# Glucose: 132 -
# BloodPressure: 74 -
# SkinThickness:20 -
# Insulin:21 -
# BMI:24.3 -
# DiabetesPedigreeFunction:128 -
# Age: 37

# %%
patient = np.array([2,132,74,20,21,24.3,128,37])

# scaling
patient = scaler.transform(patient.reshape(1, -1))

y_patient = SVMlinear.predict(patient.reshape(1,-1))
print(y_patient)
if y_patient == 0:
    print('Patiënt heeft geen diabetes')
else:
    print('Patiënt heeft diabetes')
# Out:
# [0]
# Patiënt heeft geen diabetes

# %% [markdown]
# # SVM met kernel

# %% [markdown]
# ## Initialiseren en trainen van de SVM

# %%
SVMkernel = svm.SVC(kernel='rbf',C=0.1,gamma=0.1)
#SVMkernel = svm.SVC(kernel='poly',C=1)
SVMkernel.fit(X_train, y_train)
# Out:
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ## Inlezen van de test set

# %% [markdown]
# ## Testen van het model op test set

# %%
y_pred = SVMkernel.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.85      0.85      1223
#           1       0.85      0.86      0.86      1276
#
# avg / total       0.85      0.85      0.85      2499
#
# [[1037  186]
#  [ 184 1092]]
# 85.1940776311

# %% [markdown]
# ## Predictie op een nieuwe patiënt
#
# Pregnancies:2 -
# Glucose: 132 -
# BloodPressure: 74 -
# SkinThickness:20 -
# Insulin:21 -
# BMI:24.3 -
# DiabetesPedigreeFunction:128 -
# Age: 37

# %%
patient = np.array([2,132,74,20,21,24.3,128,37])

# scaling
patient = scaler.transform(patient.reshape(1, -1))

y_patient = SVMmodel.predict(patient.reshape(1,-1))
print(y_patient)
if y_patient == 0:
    print('Patiënt heeft geen diabetes')
else:
    print('Patiënt heeft diabetes')
# Out:
# [0]
# Patiënt heeft geen diabetes

# %% [markdown]
# # Gridsearch en cross-validation

# %% [markdown]
# ## Gridsearch op logistic regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
paramaters = [
             {'C' : [0.001, 0.01, 0.1, 1, 10, 100, 1000,10000, 100000]}                                       
             ]
grid_search = GridSearchCV(estimator = model, 
                           param_grid = paramaters,
                           scoring = 'accuracy',
                           cv = 4,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

best_accuracy = grid_search.best_score_ 
best_parameters = grid_search.best_params_  

print('Best accuracy : ', grid_search.best_score_)
print('Best parameters :', grid_search.best_params_  )

y_pred = grid_search.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
# Best accuracy :  0.869
# Best parameters : {'C': 1}
#              precision    recall  f1-score   support
#
#           0       0.86      0.85      0.85      1223
#           1       0.86      0.87      0.86      1276
#
# avg / total       0.86      0.86      0.86      2499
#
# [[1037  186]
#  [ 168 1108]]
# 85.8343337335

# %% [markdown]
# ## Gridsearch op SVM

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

model = SVC()
paramaters = [ 
        {'kernel': ['linear'], 'C': np.linspace(1,20,100)},
        {'kernel': ['rbf'], 'C': [1, 10], 'gamma': [0.0001, 0.001, 0.01, 0.1, 0.2]},
        {'kernel': ['poly'], 'C':[1, 10]} ]
grid_search = GridSearchCV(estimator = model, 
                           param_grid = paramaters,
                           scoring = 'accuracy',
                           cv = 4,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

best_accuracy = grid_search.best_score_ 
best_parameters = grid_search.best_params_  

print('Best accuracy : ', grid_search.best_score_)
print('Best parameters :', grid_search.best_params_  )

y_pred = grid_search.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
# Best accuracy :  0.8693
# Best parameters : {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#              precision    recall  f1-score   support
#
#           0       0.86      0.85      0.85      1223
#           1       0.85      0.87      0.86      1276
#
# avg / total       0.86      0.86      0.86      2499
#
# [[1034  189]
#  [ 171 1105]]
# 85.5942376951
