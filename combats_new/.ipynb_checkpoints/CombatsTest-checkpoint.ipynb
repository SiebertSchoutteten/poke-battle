# %%
% matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import svm

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Inlezen van de dataset en overzicht

# %%
#Inlezen van de dataset
dataset = pd.read_csv('combats_train_big.csv',';')

df = pd.DataFrame(dataset)

dataset.head(10)
# Out:
#            p1         p2  leveldif            a1           a2           a3  \
# 0  jigglypuff  sandshrew       -64    skull bash   solar beam         bite
# 1     tangela      arbok       -11    substitute   earthquake  pin missile
# 2   sandshrew   nidorina        -4   double-edge  double team      agility
# 3      pidgey   nidoran♀       -53  defense curl    constrict     egg bomb
# 4     golduck    scyther        -2       amnesia    whirlwind   bonemerang
# 5   blastoise  charizard         1       screech     strength  dizzy punch
# 6   charizard    seaking        40   sand attack  horn attack    mega kick
# 7    articuno    voltorb         2          roar         rest         roar
# 8       ditto   graveler        45     tail whip         roar   poison gas
# 9    primeape   nidoran♀       -21        harden         bite  petal dance
#
#              a4            b1            b2             b3           b4    win
# 0  seismic toss    fire blast  flamethrower  thunder punch      amnesia  False
# 1    hyper beam        growth   fury attack     sonic boom    confusion  False
# 2   bubble beam          slam   double slap      fire spin   sky attack  False
# 3      withdraw  sleep powder           fly    dizzy punch      kinesis  False
# 4     transform   karate chop          leer     poison gas   mega drain  False
# 5        splash      headbutt  quick attack        pay day         surf   True
# 6     transform   dream eater       psywave    double slap        pound   True
# 7    sonic boom   wing attack      struggle     solar beam     minimize  False
# 8          gust       barrier       recover           sing          dig   True
# 9          haze         mimic     fire spin           smog  dizzy punch  False

# %%
x = df.select_dtypes(exclude=['number']) \
                .apply(LabelEncoder().fit_transform) \
                .join(df.select_dtypes(include=['number']))
        
x.head(10)
# Out:
#     p1   p2   a1   a2   a3   a4   b1   b2   b3   b4  win  leveldif
# 0   57  117  117  126   10  113   41   45  149    4    0       -64
# 1  131    3  137   37   91   63   53   49  127   20    0       -11
# 2  117   89   33   32    3   16  119   31   43  118    0        -4
# 3  101   87   26   21   38  163  121   47   29   70    0       -53
# 4   45  119    4  161   14  154   69   73   92   79    0        -2
# 5    8   13  112  132   29  129   58   99   88  140    1         1
# 6   13  121  110   60   80  154   35   98   31   95    1        40
# 7    5  141  106  105  106  127  162  134  126   84    0         2
# 8   22   47  144  106   92   55    7  103  116   27    1        45
# 9  109   87   56   10   90   57   83   43  123   29    0       -21

# %%
# Beschrijvende statistische analyse
x.describe()
# Out:
#                    p1              p2              a1              a2  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        74.461496       74.509657       81.477335       81.478873
# std         43.299304       43.284250       47.324837       47.381965
# min          0.000000        0.000000        0.000000        0.000000
# 25%         37.000000       37.000000       40.000000       40.000000
# 50%         74.000000       74.000000       82.000000       81.000000
# 75%        112.000000      112.000000      122.000000      123.000000
# max        149.000000      149.000000      163.000000      163.000000
#
#                    a3              a4              b1              b2  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        81.444122       81.549960       81.393235       81.506658
# std         47.351128       47.330371       47.303580       47.337498
# min          0.000000        0.000000        0.000000        0.000000
# 25%         40.000000       41.000000       40.000000       41.000000
# 50%         81.000000       81.000000       81.000000       82.000000
# 75%        122.000000      123.000000      122.000000      122.000000
# max        163.000000      163.000000      163.000000      163.000000
#
#                    b3              b4             win        leveldif
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        81.501959       81.506717        0.499978        0.043972
# std         47.340731       47.338900        0.500000       39.997960
# min          0.000000        0.000000        0.000000      -97.000000
# 25%         40.000000       41.000000        0.000000      -29.000000
# 50%         82.000000       82.000000        0.000000        0.000000
# 75%        122.000000      123.000000        1.000000       29.000000
# max        163.000000      163.000000        1.000000       97.000000

# %% [markdown]
# # Visualiseren van de dataset

# %%
# Histogram
x.hist(figsize=(15,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E60588D7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E605B90908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E605BFEF98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E605C5E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E605F3C048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E605F3C080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E605FFEF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E60683AB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E606876E10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E6069054A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E606918358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E6069D12E8>]], dtype=object)

# %%
# Box plot
x.plot(kind= 'box' , subplots=True, layout=(4,4), sharex=False, sharey=False, figsize=(10,8))
# Out:
# p1              Axes(0.125,0.71587;0.168478x0.16413)
# p2           Axes(0.327174,0.71587;0.168478x0.16413)
# a1           Axes(0.529348,0.71587;0.168478x0.16413)
# a2           Axes(0.731522,0.71587;0.168478x0.16413)
# a3             Axes(0.125,0.518913;0.168478x0.16413)
# a4          Axes(0.327174,0.518913;0.168478x0.16413)
# b1          Axes(0.529348,0.518913;0.168478x0.16413)
# b2          Axes(0.731522,0.518913;0.168478x0.16413)
# b3             Axes(0.125,0.321957;0.168478x0.16413)
# b4          Axes(0.327174,0.321957;0.168478x0.16413)
# win         Axes(0.529348,0.321957;0.168478x0.16413)
# leveldif    Axes(0.731522,0.321957;0.168478x0.16413)
# dtype: object

# %%
# Correlation plot
Corr=x[x.columns].corr() 
sns.heatmap(Corr, annot=True)

# %% [markdown]
# # Preprocessing en opsplitsen in training en test set

# %%
# Opsplitsen in features en targets

features = list(x[['p1','p2','leveldif','a1','a2','a3','a4','b1','b2','b3','b4']])
print(features),
X = x[features].values

y= x['win'].values

#Data scalen
scaler = MinMaxScaler()  # Default behavior is to scale to [0,1]
X = scaler.fit_transform(X)


# Opsplitsen van data in een training en test set

print(X.shape)
# Out:
# ['p1', 'p2', 'leveldif', 'a1', 'a2', 'a3', 'a4', 'b1', 'b2', 'b3', 'b4']
# (1000000, 11)
# D:\Programs\Anaconda\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# # Logistic regression

# %% [markdown]
# ## Initialiseren en trainen van de logistic regression classifier

# %%
#Inlezen van de dataset
dataset2 = pd.read_csv('combats_test_big.csv',';')

df2 = pd.DataFrame(dataset2)

dataset2.head(10)
# Out:
#            p1         p2  leveldif            a1           a2            a3  \
# 0     flareon  bulbasaur        53          haze   sky attack    leech seed
# 1    nidoking   slowpoke         1  swords dance   hydro pump  focus energy
# 2      kabuto   alakazam       -25           dig        swift    substitute
# 3  charmander     weedle       -27       reflect  string shot   dragon rage
# 4      machop      doduo        71         mimic  double-edge  sleep powder
# 5       ekans  dragonite         2          lick  horn attack          sing
# 6  weepinbell      golem       -65     jump kick  horn attack         swift
# 7     snorlax     kabuto        83       psywave      agility  rolling kick
# 8     scyther  hitmonlee        21   thunderbolt    body slam    tri attack
# 9      gastly     golbat       -15       kinesis         roar  focus energy
#
#             a4              b1            b2            b3             b4  \
# 0    whirlwind  high jump kick          peck      ice beam      water gun
# 1  double team     smokescreen      meditate         slash          growl
# 2         lick           ember   aurora beam          bite         tackle
# 3  night shade            haze     fire spin  sleep powder           mist
# 4     struggle         agility  focus energy         clamp      water gun
# 5     teleport    swords dance      withdraw     take down    soft-boiled
# 6         mist     pin missile          peck           fly     horn drill
# 7   crabhammer       explosion      low kick        sludge     crabhammer
# 8    vine whip            bind       psychic   mirror move           gust
# 9  double kick    poison sting       counter    earthquake  poison powder
#
#      win
# 0   True
# 1   True
# 2  False
# 3  False
# 4   True
# 5  False
# 6  False
# 7   True
# 8   True
# 9  False

# %%
x2 = df2.select_dtypes(exclude=['number']) \
                .apply(LabelEncoder().fit_transform) \
                .join(df2.select_dtypes(include=['number']))
        
x2.head(10)
# Out:
#     p1   p2   a1   a2   a3   a4   b1   b2   b3   b4  win  leveldif
# 0   38    9   57  118   72  161   59   89   66  159    1        53
# 1   85  125  142   62   48   32  124   78  120   52    1         1
# 2   60    2   27  141  137   74   39    5   10  143    0       -25
# 3   14  144  104  133   34   87   57   43  121   86    0       -27
# 4   72   24   83   33  121  134    3   48   17  159    1        71
# 5   31   26   74   60  116  146  142  163  145  125    0         2
# 6  145   46   68   60  141   86   91   89   47   61    0       -65
# 7  126   60   98    3  109   24   40   77  122   24    1        83
# 8  119   53  152   12  155  158    9   97   85   55    1        21
# 9   39   43   70  106   48   30   94   23   37   93    0       -15

# %%
# Opsplitsen in features en targets

features = list(x2[['p1','p2','leveldif','a1','a2','a3','a4','b1','b2','b3','b4']])
print(features)
X_test = x2[features].values

y_test= x2['win'].values

#Data scalen
scaler = MinMaxScaler()  # Default behavior is to scale to [0,1]
X = scaler.fit_transform(X)

# Opsplitsen van data in een training en test set

print(X_test.shape)
# Out:
# ['p1', 'p2', 'leveldif', 'a1', 'a2', 'a3', 'a4', 'b1', 'b2', 'b3', 'b4']
# (249999, 11)

# %%
# Initialiseren van de logistic regression classifier

logreg = linear_model.LogisticRegression(C=1,class_weight= None)

#logreg = linear_model.LogisticRegression(C=1,class_weight= 'balanced')

# Training van het model
logreg.fit(X, y)

print('De bias = theta_0: ', logreg.intercept_)
print('De coefficienten theta: ',logreg.coef_)
# Out:
# De bias = theta_0:  [-7.93318693]
# De coefficienten theta:  [[  7.48392192e-02  -8.26165928e-02   1.58667886e+01  -3.55405138e-02
#    -5.88382135e-02  -2.03832260e-02   6.20514401e-03   3.74565997e-02
#     2.63190224e-02   3.23525458e-02   1.53313675e-02]]

# %% [markdown]
# ## Testen van het model op de test set

# %%
# Testen van het model op de test set

y_pred = logreg.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.87      0.87    124783
#           1       0.87      0.86      0.87    125216
#
# avg / total       0.87      0.87      0.87    249999
#
# [[108632  16151]
#  [ 17334 107882]]
# 86.6059464238

# %% [markdown]
# ## Predictie op een nieuwe patiënt
#
# Pregnancies:2 -
# Glucose: 132 -
# BloodPressure: 74 -
# SkinThickness:20 -
# Insulin:21 -
# BMI:24.3 -
# DiabetesPedigreeFunction:128 -
# Age: 37

# %%
patient = np.array([2,132,74,20,21,24.3,128,37])

# scaling
patient = scaler.transform(patient.reshape(1, -1))

print(patient)
y_patient = logreg.predict(patient.reshape(1,-1))
y_patient_prob = logreg.predict_proba(patient.reshape(1,-1))
print(y_patient)
print(y_patient_prob)

if y_patient == 0:
    print('Patiënt heeft geen diabetes')
else:
    print('Patiënt heeft diabetes')
# Out:
# [[-0.41420941  0.30209759  0.25992289 -0.84670314 -1.13434945 -1.2724308
#   -1.0725144   0.62170047]]
# [0]
# [[ 0.85859249  0.14140751]]
# Patiënt heeft geen diabetes

# %% [markdown]
# # SVM zonder kernel (= lineaire kernel)

# %% [markdown]
# ## Initialiseren en trainen van SVM

# %%
SVMlinear = svm.SVC(kernel='linear',C=0.1,cache_size=7000)
SVMlinear.fit(X, y)

# %% [markdown]
# ## Testen van het model op test set

# %%
y_pred = SVMlinear.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.74      0.90      0.81        48
#           1       0.72      0.46      0.57        28
#
# avg / total       0.73      0.74      0.72        76
#
# [[43  5]
#  [15 13]]
# 73.6842105263

# %% [markdown]
# ## Predictie op een nieuwe patiënt
#
# Pregnancies:2 -
# Glucose: 132 -
# BloodPressure: 74 -
# SkinThickness:20 -
# Insulin:21 -
# BMI:24.3 -
# DiabetesPedigreeFunction:128 -
# Age: 37

# %%
patient = np.array([2,132,74,20,21,24.3,128,37])

# scaling
patient = scaler.transform(patient.reshape(1, -1))

y_patient = SVMlinear.predict(patient.reshape(1,-1))
print(y_patient)
if y_patient == 0:
    print('Patiënt heeft geen diabetes')
else:
    print('Patiënt heeft diabetes')
# Out:
# [0]
# Patiënt heeft geen diabetes

# %% [markdown]
# # SVM met kernel

# %% [markdown]
# ## Initialiseren en trainen van de SVM

# %%
SVMkernel = svm.SVC(kernel='rbf',C=0.1,gamma=0.1)
#SVMkernel = svm.SVC(kernel='poly',C=1)
SVMkernel.fit(X, y)
# Out:
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ## Inlezen van de test set

# %% [markdown]
# ## Testen van het model op test set

# %%
y_pred = SVMkernel.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.69      0.98      0.81        48
#           1       0.88      0.25      0.39        28
#
# avg / total       0.76      0.71      0.66        76
#
# [[47  1]
#  [21  7]]
# 71.0526315789

# %% [markdown]
# ## Predictie op een nieuwe patiënt
#
# Pregnancies:2 -
# Glucose: 132 -
# BloodPressure: 74 -
# SkinThickness:20 -
# Insulin:21 -
# BMI:24.3 -
# DiabetesPedigreeFunction:128 -
# Age: 37

# %%
patient = np.array([2,132,74,20,21,24.3,128,37])

# scaling
patient = scaler.transform(patient.reshape(1, -1))

y_patient = SVMmodel.predict(patient.reshape(1,-1))
print(y_patient)
if y_patient == 0:
    print('Patiënt heeft geen diabetes')
else:
    print('Patiënt heeft diabetes')
# Out:
# [0]
# Patiënt heeft geen diabetes

# %% [markdown]
# # Gridsearch en cross-validation

# %% [markdown]
# ## Gridsearch op logistic regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
paramaters = [
             {'C' : [0.001, 0.01, 0.1, 1, 10, 100, 1000,10000, 100000]}                                       
             ]
grid_search = GridSearchCV(estimator = model, 
                           param_grid = paramaters,
                           scoring = 'accuracy',
                           cv = 4,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

best_accuracy = grid_search.best_score_ 
best_parameters = grid_search.best_params_  

print('Best accuracy : ', grid_search.best_score_)
print('Best parameters :', grid_search.best_params_  )

y_pred = grid_search.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
# Best accuracy :  0.802631578947
# Best parameters : {'C': 100}
#              precision    recall  f1-score   support
#
#           0       0.73      0.85      0.79        48
#           1       0.65      0.46      0.54        28
#
# avg / total       0.70      0.71      0.70        76
#
# [[41  7]
#  [15 13]]
# 71.0526315789

# %% [markdown]
# ## Gridsearch op SVM

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

model = SVC()
paramaters = [ 
        {'kernel': ['linear'], 'C': np.linspace(1,20,100)},
        {'kernel': ['rbf'], 'C': [1, 10], 'gamma': [0.0001, 0.001, 0.01, 0.1, 0.2]},
        {'kernel': ['poly'], 'C':[1, 10]} ]
grid_search = GridSearchCV(estimator = model, 
                           param_grid = paramaters,
                           scoring = 'accuracy',
                           cv = 4,
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)

best_accuracy = grid_search.best_score_ 
best_parameters = grid_search.best_params_  

print('Best accuracy : ', grid_search.best_score_)
print('Best parameters :', grid_search.best_params_  )

y_pred = grid_search.predict(X_test)
print(classification_report(y_test, y_pred))

cf = confusion_matrix(y_test, y_pred)
print(cf)
print(accuracy_score(y_test, y_pred) * 100)
# Out:
# Best accuracy :  0.805921052632
# Best parameters : {'C': 1.3838383838383839, 'kernel': 'linear'}
#              precision    recall  f1-score   support
#
#           0       0.75      0.88      0.81        48
#           1       0.70      0.50      0.58        28
#
# avg / total       0.73      0.74      0.73        76
#
# [[42  6]
#  [14 14]]
# 73.6842105263
